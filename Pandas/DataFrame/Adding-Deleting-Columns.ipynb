# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
frame = pd.read_csv('../DataSeries/course-files/mcdonalds.csv', usecols=['Item', 'Category', 'TotalFat', 'Sugars', 'Protein',
                                                                        'Cholesterol'])

# %%
frame.head()
# Out:
#     Category                              Item  TotalFat  Cholesterol  Sugars  \
# 0  Breakfast                      Egg McMuffin      13.0          260       3
# 1  Breakfast                 Egg White Delight       8.0           25       3
# 2  Breakfast                  Sausage McMuffin      23.0           45       2
# 3  Breakfast         Sausage McMuffin with Egg      28.0          285       2
# 4  Breakfast  Sausage McMuffin with Egg Whites      23.0           50       2
#
#    Protein
# 0       17
# 1       18
# 2       14
# 3       21
# 4       21

# %%
frame.TotalFat.head() #1 sposób wyświetlenia danych z kolumny
# Out:
# 0    13.0
# 1     8.0
# 2    23.0
# 3    28.0
# 4    23.0
# Name: TotalFat, dtype: float64

# %%
frame['TotalFat'].head() #2 sposób
# Out:
# 0    13.0
# 1     8.0
# 2    23.0
# 3    28.0
# 4    23.0
# Name: TotalFat, dtype: float64

# %% [markdown]
# # Dodawanie kolumn

# %%
frame['TotalFat0'] = 0

# %%
frame.head()
# Out:
#     Category                              Item  TotalFat  Cholesterol  Sugars  \
# 0  Breakfast                      Egg McMuffin      13.0          260       3
# 1  Breakfast                 Egg White Delight       8.0           25       3
# 2  Breakfast                  Sausage McMuffin      23.0           45       2
# 3  Breakfast         Sausage McMuffin with Egg      28.0          285       2
# 4  Breakfast  Sausage McMuffin with Egg Whites      23.0           50       2
#
#    Protein  TotalFat0
# 0       17          0
# 1       18          0
# 2       14          0
# 3       21          0
# 4       21          0

# %%
SugarAndFat = frame.Sugars + frame.TotalFat

# %%
frame['SugarAndFat'] = SugarAndFat

# %%
SugarAndFat.head()
# Out:
# 0    16.0
# 1    11.0
# 2    25.0
# 3    30.0
# 4    25.0
# dtype: float64

# %%
frame['SugarAndProtein'] = frame.Sugars + frame.Protein
frame.head()
# Out:
#     Category                              Item  TotalFat  Cholesterol  Sugars  \
# 0  Breakfast                      Egg McMuffin      13.0          260       3
# 1  Breakfast                 Egg White Delight       8.0           25       3
# 2  Breakfast                  Sausage McMuffin      23.0           45       2
# 3  Breakfast         Sausage McMuffin with Egg      28.0          285       2
# 4  Breakfast  Sausage McMuffin with Egg Whites      23.0           50       2
#
#    Protein  TotalFat0  SugarAndFat  SugarAndProtein
# 0       17          0         16.0               20
# 1       18          0         11.0               21
# 2       14          0         25.0               16
# 3       21          0         30.0               23
# 4       21          0         25.0               23

# %%
frame.insert(loc=2, column='SPF', value=frame.Sugars+frame.Protein+frame.TotalFat) #loc w którym miejscu nowa kolumna
                                    #ma się pojawić, potem nazwa kolumny i value inicjuje wartości nowej kolumny

# %%
frame.head()
# Out:
#     Category                              Item   SPF  TotalFat  Cholesterol  \
# 0  Breakfast                      Egg McMuffin  33.0      13.0          260
# 1  Breakfast                 Egg White Delight  29.0       8.0           25
# 2  Breakfast                  Sausage McMuffin  39.0      23.0           45
# 3  Breakfast         Sausage McMuffin with Egg  51.0      28.0          285
# 4  Breakfast  Sausage McMuffin with Egg Whites  46.0      23.0           50
#
#    Sugars  Protein  TotalFat0  SugarAndFat  SugarAndProtein
# 0       3       17          0         16.0               20
# 1       3       18          0         11.0               21
# 2       2       14          0         25.0               16
# 3       2       21          0         30.0               23
# 4       2       21          0         25.0               23

# %% [markdown]
# # Usuwanie kolumn

# %%
del frame['SugarAndProtein']

# %%
frame.head()
# Out:
#     Category                              Item   SPF  TotalFat  Cholesterol  \
# 0  Breakfast                      Egg McMuffin  33.0      13.0          260
# 1  Breakfast                 Egg White Delight  29.0       8.0           25
# 2  Breakfast                  Sausage McMuffin  39.0      23.0           45
# 3  Breakfast         Sausage McMuffin with Egg  51.0      28.0          285
# 4  Breakfast  Sausage McMuffin with Egg Whites  46.0      23.0           50
#
#    Sugars  Protein  TotalFat0  SugarAndFat
# 0       3       17          0         16.0
# 1       3       18          0         11.0
# 2       2       14          0         25.0
# 3       2       21          0         30.0
# 4       2       21          0         25.0

# %%
#del frame.SugarAndFat error
